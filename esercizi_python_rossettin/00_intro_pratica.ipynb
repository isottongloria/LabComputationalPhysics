# %% [markdown]
# # Esercizi introduttivi
#
# Mini-esercizi per riprendere confidenza con Python e Jupyter.

# %% [markdown]
# ## Istruzioni
# - Risolvi ogni esercizio nelle celle di codice subito sotto la consegna.
# - Mantieni codice e output ordinati.
# - Se utile, aggiungi brevi commenti alle scelte implementative.

# %% [markdown]
# ### Esercizio 1
# Crea tre variabili (`nome`, `eta`, `citta`) e stampa una frase unica con f-string.

# %%
# Scrivi qui la tua soluzione

# %% [markdown]
# ### Esercizio 2
# Dato `temperatura_c = 22.5`, calcola e stampa la temperatura in Fahrenheit.

# %%
# Scrivi qui la tua soluzione

# %% [markdown]
# ### Esercizio 3
# Scrivi una cella che chieda (con `input`) due numeri e stampi somma, differenza e prodotto.

# %%
# Scrivi qui la tua soluzione

# %% [markdown]
# ### Esercizio 4
# Crea una lista di 5 hobby, poi stampa il primo, l'ultimo e la lunghezza della lista.

# %%
# Scrivi qui la tua soluzione

# %% [markdown]
# ### Esercizio 5
# Scrivi una funzione `saluta(nome)` che ritorna una stringa di saluto personalizzata.

# %%
# Scrivi qui la tua soluzione

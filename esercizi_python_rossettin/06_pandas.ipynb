# %% [markdown]
# # Pandas
#
# Manipolazione tabelle: filtri, groupby, merge.

# %% [markdown]
# ## Istruzioni
# - Risolvi ogni esercizio nelle celle di codice subito sotto la consegna.
# - Mantieni codice e output ordinati.
# - Se utile, aggiungi brevi commenti alle scelte implementative.

# %% [markdown]
# ### Esercizio 1
# Crea un DataFrame con almeno 30 righe su prenotazioni hotel (città, notti, prezzo, stagione).

# %%
# Scrivi qui la tua soluzione

# %% [markdown]
# ### Esercizio 2
# Filtra solo le prenotazioni estive con prezzo > 120.

# %%
# Scrivi qui la tua soluzione

# %% [markdown]
# ### Esercizio 3
# Calcola prezzo medio per città e ordina in senso decrescente.

# %%
# Scrivi qui la tua soluzione

# %% [markdown]
# ### Esercizio 4
# Crea un secondo DataFrame con informazioni extra sulle città e fai una `merge`.

# %%
# Scrivi qui la tua soluzione

# %% [markdown]
# ### Esercizio 5
# Aggiungi una colonna `costo_totale = notti * prezzo` e trova le 5 prenotazioni più care.

# %%
# Scrivi qui la tua soluzione

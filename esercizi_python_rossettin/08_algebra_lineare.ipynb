# %% [markdown]
# # Algebra lineare numerica
#
# Matrici, sistemi lineari, autovalori con NumPy.

# %% [markdown]
# ## Istruzioni
# - Risolvi ogni esercizio nelle celle di codice subito sotto la consegna.
# - Mantieni codice e output ordinati.
# - Se utile, aggiungi brevi commenti alle scelte implementative.

# %% [markdown]
# ### Esercizio 1
# Definisci due matrici 3x3 e calcola somma, prodotto e determinante.

# %%
# Scrivi qui la tua soluzione

# %% [markdown]
# ### Esercizio 2
# Risolvi un sistema lineare `Ax=b` con `np.linalg.solve`.

# %%
# Scrivi qui la tua soluzione

# %% [markdown]
# ### Esercizio 3
# Verifica numericamente che `A @ A_inv` sia vicina alla matrice identità.

# %%
# Scrivi qui la tua soluzione

# %% [markdown]
# ### Esercizio 4
# Calcola autovalori e autovettori di una matrice simmetrica 3x3.

# %%
# Scrivi qui la tua soluzione

# %% [markdown]
# ### Esercizio 5
# Confronta norma L1, L2 e infinito di un vettore a tua scelta.

# %%
# Scrivi qui la tua soluzione

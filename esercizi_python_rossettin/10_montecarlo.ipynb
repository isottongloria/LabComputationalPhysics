# %% [markdown]
# # Monte Carlo
#
# Simulazioni stocastiche e stima di quantità numeriche.

# %% [markdown]
# ## Istruzioni
# - Risolvi ogni esercizio nelle celle di codice subito sotto la consegna.
# - Mantieni codice e output ordinati.
# - Se utile, aggiungi brevi commenti alle scelte implementative.

# %% [markdown]
# ### Esercizio 1
# Stima il valore di pi greco campionando punti nel quadrato unitario.

# %%
# Scrivi qui la tua soluzione

# %% [markdown]
# ### Esercizio 2
# Ripeti la stima per N = 1e3, 1e4, 1e5 e confronta l'errore.

# %%
# Scrivi qui la tua soluzione

# %% [markdown]
# ### Esercizio 3
# Simula il lancio di due dadi per 50.000 prove e stima la probabilità di somma 7.

# %%
# Scrivi qui la tua soluzione

# %% [markdown]
# ### Esercizio 4
# Stima un integrale semplice con campionamento uniforme (scegli funzione e intervallo).

# %%
# Scrivi qui la tua soluzione

# %% [markdown]
# ### Esercizio 5
# Visualizza come l'errore decresce al crescere del numero di campioni.

# %%
# Scrivi qui la tua soluzione

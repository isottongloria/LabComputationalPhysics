# %% [markdown]
# # Numpy
#
# Array, slicing, operazioni vettoriali e broadcasting.

# %% [markdown]
# ## Istruzioni
# - Risolvi ogni esercizio nelle celle di codice subito sotto la consegna.
# - Mantieni codice e output ordinati.
# - Se utile, aggiungi brevi commenti alle scelte implementative.

# %% [markdown]
# ### Esercizio 1
# Crea un array 4x5 con numeri casuali interi tra 10 e 99.

# %%
# Scrivi qui la tua soluzione

# %% [markdown]
# ### Esercizio 2
# Estrai la seconda riga e la quarta colonna; calcolane media e deviazione standard.

# %%
# Scrivi qui la tua soluzione

# %% [markdown]
# ### Esercizio 3
# Sostituisci tutti i valori pari dell'array con `-1` senza usare cicli espliciti.

# %%
# Scrivi qui la tua soluzione

# %% [markdown]
# ### Esercizio 4
# Costruisci due vettori compatibili e mostra un esempio di broadcasting.

# %%
# Scrivi qui la tua soluzione

# %% [markdown]
# ### Esercizio 5
# Dato un array 1D, calcola cumulata (`cumsum`) e differenze tra elementi consecutivi.

# %%
# Scrivi qui la tua soluzione

# %% [markdown]
# # Bash + Python in Jupyter
#
# Uso pratico di comandi shell e loro integrazione con Python.

# %% [markdown]
# ## Istruzioni
# - Risolvi ogni esercizio nelle celle di codice subito sotto la consegna.
# - Mantieni codice e output ordinati.
# - Se utile, aggiungi brevi commenti alle scelte implementative.

# %% [markdown]
# ### Esercizio 1
# Usa `!pwd` e `!ls` per esplorare la cartella di lavoro del notebook.

# %%
# Scrivi qui la tua soluzione

# %% [markdown]
# ### Esercizio 2
# Crea da shell una cartella `dati_tmp` e tre file di testo al suo interno.

# %%
# Scrivi qui la tua soluzione

# %% [markdown]
# ### Esercizio 3
# Con Python, leggi i nomi dei file in `dati_tmp` e salvali in una lista ordinata.

# %%
# Scrivi qui la tua soluzione

# %% [markdown]
# ### Esercizio 4
# Esegui da Python un comando shell (`subprocess`) che conti quante righe ha un file.

# %%
# Scrivi qui la tua soluzione

# %% [markdown]
# ### Esercizio 5
# Elimina `dati_tmp` solo alla fine del notebook, dopo aver verificato i contenuti.

# %%
# Scrivi qui la tua soluzione

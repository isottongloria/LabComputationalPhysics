# %% [markdown]
# # Algoritmi e complessità
#
# Ricerca, ordinamento e misure tempo di esecuzione.

# %% [markdown]
# ## Istruzioni
# - Risolvi ogni esercizio nelle celle di codice subito sotto la consegna.
# - Mantieni codice e output ordinati.
# - Se utile, aggiungi brevi commenti alle scelte implementative.

# %% [markdown]
# ### Esercizio 1
# Implementa ricerca lineare e ricerca binaria su liste ordinate.

# %%
# Scrivi qui la tua soluzione

# %% [markdown]
# ### Esercizio 2
# Confronta i tempi medi su liste di dimensione 1e3, 1e4, 1e5.

# %%
# Scrivi qui la tua soluzione

# %% [markdown]
# ### Esercizio 3
# Implementa `bubble sort` e confrontalo con `sorted` su input casuali.

# %%
# Scrivi qui la tua soluzione

# %% [markdown]
# ### Esercizio 4
# Scrivi una funzione ricorsiva per Fibonacci e una iterativa; confronta performance.

# %%
# Scrivi qui la tua soluzione

# %% [markdown]
# ### Esercizio 5
# Commenta in 4-6 righe i risultati in termini di complessità.

# %%
# Scrivi qui la tua soluzione

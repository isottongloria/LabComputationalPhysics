# %% [markdown]
# # Rappresentazione dei numeri
#
# Esercizi su basi numeriche, arrotondamenti e precisione.

# %% [markdown]
# ## Istruzioni
# - Risolvi ogni esercizio nelle celle di codice subito sotto la consegna.
# - Mantieni codice e output ordinati.
# - Se utile, aggiungi brevi commenti alle scelte implementative.

# %% [markdown]
# ### Esercizio 1
# Converti il numero decimale `157` in binario, ottale ed esadecimale usando Python.

# %%
# Scrivi qui la tua soluzione

# %% [markdown]
# ### Esercizio 2
# Confronta `0.1 + 0.2` con `0.3` e spiega con un commento il risultato ottenuto.

# %%
# Scrivi qui la tua soluzione

# %% [markdown]
# ### Esercizio 3
# Scrivi una funzione che arrotonda un numero a `n` cifre decimali senza usare `round`.

# %%
# Scrivi qui la tua soluzione

# %% [markdown]
# ### Esercizio 4
# Calcola errore assoluto e relativo tra valore vero `42` e misura `41.6`.

# %%
# Scrivi qui la tua soluzione

# %% [markdown]
# ### Esercizio 5
# Genera una tabella (lista di tuple) con potenze di 2 da `2^0` a `2^16`.

# %%
# Scrivi qui la tua soluzione

# %% [markdown]
# # Visualizzazione dati
#
# Grafici chiari con matplotlib/seaborn.

# %% [markdown]
# ## Istruzioni
# - Risolvi ogni esercizio nelle celle di codice subito sotto la consegna.
# - Mantieni codice e output ordinati.
# - Se utile, aggiungi brevi commenti alle scelte implementative.

# %% [markdown]
# ### Esercizio 1
# Genera una serie temporale sintetica (ad es. 60 giorni) e crea un line plot leggibile.

# %%
# Scrivi qui la tua soluzione

# %% [markdown]
# ### Esercizio 2
# Crea un bar plot con confronto tra 5 categorie di spesa.

# %%
# Scrivi qui la tua soluzione

# %% [markdown]
# ### Esercizio 3
# Mostra in un istogramma la distribuzione di 500 valori generati casualmente.

# %%
# Scrivi qui la tua soluzione

# %% [markdown]
# ### Esercizio 4
# Costruisci uno scatter plot tra due variabili correlate con rumore.

# %%
# Scrivi qui la tua soluzione

# %% [markdown]
# ### Esercizio 5
# Per ogni grafico: aggiungi titolo, etichette assi e griglia leggera.

# %%
# Scrivi qui la tua soluzione

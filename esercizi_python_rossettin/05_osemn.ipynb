# %% [markdown]
# # Workflow OSEMN
#
# Obtain, Scrub, Explore, Model, iNterpret su un mini-dataset.

# %% [markdown]
# ## Istruzioni
# - Risolvi ogni esercizio nelle celle di codice subito sotto la consegna.
# - Mantieni codice e output ordinati.
# - Se utile, aggiungi brevi commenti alle scelte implementative.

# %% [markdown]
# ### Esercizio 1
# Crea un piccolo dataset (almeno 20 righe) su vendite mensili con colonne: mese, categoria, importo.

# %%
# Scrivi qui la tua soluzione

# %% [markdown]
# ### Esercizio 2
# Inserisci volontariamente 3 valori mancanti e poi gestiscili con una strategia motivata.

# %%
# Scrivi qui la tua soluzione

# %% [markdown]
# ### Esercizio 3
# Esplora il dataset: statistiche descrittive e una domanda a cui vuoi rispondere.

# %%
# Scrivi qui la tua soluzione

# %% [markdown]
# ### Esercizio 4
# Costruisci un modello semplice (anche solo regressione lineare) per prevedere `importo`.

# %%
# Scrivi qui la tua soluzione

# %% [markdown]
# ### Esercizio 5
# Interpreta il risultato in massimo 5 righe: cosa funziona e cosa no.

# %%
# Scrivi qui la tua soluzione

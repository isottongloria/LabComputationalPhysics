# %% [markdown]
# # Fondamentali Python
#
# Controllo di flusso, funzioni e strutture dati di base.

# %% [markdown]
# ## Istruzioni
# - Risolvi ogni esercizio nelle celle di codice subito sotto la consegna.
# - Mantieni codice e output ordinati.
# - Se utile, aggiungi brevi commenti alle scelte implementative.

# %% [markdown]
# ### Esercizio 1
# Scrivi una funzione che riceve un numero e ritorna `True` se è pari, `False` altrimenti.

# %%
# Scrivi qui la tua soluzione

# %% [markdown]
# ### Esercizio 2
# Data una lista di interi, crea una nuova lista con i quadrati solo dei numeri dispari.

# %%
# Scrivi qui la tua soluzione

# %% [markdown]
# ### Esercizio 3
# Conta quante vocali contiene una stringa (maiuscole/minuscole).

# %%
# Scrivi qui la tua soluzione

# %% [markdown]
# ### Esercizio 4
# Simula un piccolo registro voti: dizionario `studente -> voto`, poi calcola media e voto massimo.

# %%
# Scrivi qui la tua soluzione

# %% [markdown]
# ### Esercizio 5
# Scrivi una funzione che riceve una frase e restituisce un dizionario con frequenza di ogni parola.

# %%
# Scrivi qui la tua soluzione
